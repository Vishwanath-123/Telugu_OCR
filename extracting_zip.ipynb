# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import time

# Replace 'your_zip_file.zip' with the name of your zip file
zip_file_path = '/home/ocr/teluguOCR/html_transcriptions.zip'

# Replace 'your_extracted_folder' with the name of the folder where you want to extract the contents
extracted_folder_path = '/home/ocr/teluguOCR/html_transcriptions'

# Use the zipfile library to extract the contents
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
  zip_ref.extractall(extracted_folder_path)

# %%
time.sleep(2400)
# drive.flush_and_unmount()

# %%
time.sleep(36000)

# %%
import os
extracted_folder_path = '/content/drive/MyDrive/Telugu_OCR/Dataset/Images'
subfolders= os.listdir(extracted_folder_path)

for x in subfolders:
  if len(os.listdir(extracted_folder_path + '/' +x)) != 1000:
    print(x)
# Out:
# subFolder106
